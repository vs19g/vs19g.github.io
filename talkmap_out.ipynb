# %% [markdown]
# # Leaflet cluster map of talk locations
#
# Assuming you are working in a Linux or Windows Subsystem for Linux environment, you may need to install some dependencies. Assuming a clean installation, the following will be needed:
#
# ```bash
# sudo apt install jupyter
# sudo apt install python3-pip
# pip install python-frontmatter getorg --upgrade
# ```
#
# After which you can run this from the `_talks/` directory, via:
#
# ```bash
#  jupyter nbconvert --to notebook --execute talkmap.ipynb --output talkmap_out.ipynb
# ```
#
# The `_talks/` directory contains `.md` files of all your talks. This scrapes the location YAML field from each `.md` file, geolocates it with `geopy/Nominatim`, and uses the `getorg` library to output data, HTML, and Javascript for a standalone cluster map.

# %%
# Start by installing the dependencies
# !pip install python-frontmatter getorg --upgrade
import frontmatter
import glob
import getorg
from geopy import Nominatim
from geopy.exc import GeocoderTimedOut
# Out:
# Requirement already satisfied: python-frontmatter in ./_talks/myenv/lib/python3.12/site-packages (1.1.0)
# Requirement already satisfied: getorg in ./_talks/myenv/lib/python3.12/site-packages (0.3.1)
# Requirement already satisfied: PyYAML in ./_talks/myenv/lib/python3.12/site-packages (from python-frontmatter) (6.0.3)
# Requirement already satisfied: geopy in ./_talks/myenv/lib/python3.12/site-packages (from getorg) (2.4.1)
# Requirement already satisfied: pygithub in ./_talks/myenv/lib/python3.12/site-packages (from getorg) (2.9.1)
# Requirement already satisfied: retrying in ./_talks/myenv/lib/python3.12/site-packages (from getorg) (1.4.2)
# Requirement already satisfied: geographiclib<3,>=1.52 in ./_talks/myenv/lib/python3.12/site-packages (from geopy->getorg) (2.1)
# Requirement already satisfied: pynacl>=1.4.0 in ./_talks/myenv/lib/python3.12/site-packages (from pygithub->getorg) (1.6.2)
# Requirement already satisfied: requests>=2.14.0 in ./_talks/myenv/lib/python3.12/site-packages (from pygithub->getorg) (2.33.1)
# Requirement already satisfied: pyjwt>=2.4.0 in ./_talks/myenv/lib/python3.12/site-packages (from pyjwt[crypto]>=2.4.0->pygithub->getorg) (2.12.1)
# Requirement already satisfied: typing-extensions>=4.5.0 in ./_talks/myenv/lib/python3.12/site-packages (from pygithub->getorg) (4.15.0)
# Requirement already satisfied: urllib3>=1.26.0 in ./_talks/myenv/lib/python3.12/site-packages (from pygithub->getorg) (2.6.3)
# Requirement already satisfied: cryptography>=3.4.0 in ./_talks/myenv/lib/python3.12/site-packages (from pyjwt[crypto]>=2.4.0->pygithub->getorg) (47.0.0)
# Requirement already satisfied: cffi>=2.0.0 in ./_talks/myenv/lib/python3.12/site-packages (from pynacl>=1.4.0->pygithub->getorg) (2.0.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in ./_talks/myenv/lib/python3.12/site-packages (from requests>=2.14.0->pygithub->getorg) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in ./_talks/myenv/lib/python3.12/site-packages (from requests>=2.14.0->pygithub->getorg) (3.13)
# Requirement already satisfied: certifi>=2023.5.7 in ./_talks/myenv/lib/python3.12/site-packages (from requests>=2.14.0->pygithub->getorg) (2026.4.22)
# Requirement already satisfied: pycparser in ./_talks/myenv/lib/python3.12/site-packages (from cffi>=2.0.0->pynacl>=1.4.0->pygithub->getorg) (3.0)
# Iywidgets and ipyleaflet support disabled. You must be in a Jupyter notebook to use this feature.
# Error raised:
# No module named 'ipyleaflet'
# Check that you have enabled ipyleaflet in Jupyter with:
#     jupyter nbextension enable --py ipyleaflet

# %%
# Collect the Markdown files
g = glob.glob("_talks/*.md")

# %%
# Set the default timeout, in seconds
TIMEOUT = 5

# Prepare to geolocate
geocoder = Nominatim(user_agent="academicpages.github.io")
location_dict = {}
location = ""
permalink = ""
title = ""

# %% [markdown]
# In the event that this times out with an error, double check to make sure that the location is can be properly geolocated.

# %%
# Perform geolocation
for file in g:
    # Read the file
    data = frontmatter.load(file)
    data = data.to_dict()

    # Press on if the location is not present
    if 'location' not in data:
        continue

    # Prepare the description
    title = data['title'].strip()
    venue = data['venue'].strip()
    location = data['location'].strip()
    description = f"{title}<br />{venue}; {location}"

    # Geocode the location and report the status
    try:
        location_dict[description] = geocoder.geocode(location, timeout=TIMEOUT)
        print(description, location_dict[description])
    except ValueError as ex:
        print(f"Error: geocode failed on input {location} with message {ex}")
    except GeocoderTimedOut as ex:
        print(f"Error: geocode timed out on input {location} with message {ex}")
    except Exception as ex:
        print(f"An unhandled exception occurred while processing input {location} with message {ex}")
# Out:
# Solar Water Desalination using Nanophotonics<br />BITS Pilani - Hyderabad Campus; Hyderabad, India Hyderabad, Bahadurpura mandal, Hyderabad, Telangana, India
# Neutron Star Workshop<br />BITS Pilani - Hyderabad Campus; Hyderabad, India Hyderabad, Bahadurpura mandal, Hyderabad, Telangana, India
# Upgrades to the ANASEN Active Target Detector for (alpha,p) reactions with radioactive beams<br />Gordon Research Conference for Nuclear Chemistry; New London, New Hampshire New London, Merrimack County, New Hampshire, United States
# The study of the 17 F (α,p) 20 Ne reaction rate using the ANASEN Active target detector<br />APS Division of Nuclear Physics (DNP) Fall Meeting; Boston, MA Boston, Suffolk County, Massachusetts, United States
# PlasmaSurf Summer School for Nuclear Fusion and Plasma Physics (ITER/IPFN)<br />Instituto de Plasmas e Fusão Nuclear (IPFN); Lisbon, Portugal Lisboa, Portugal
# The study of the 27 Al (α,p) reaction using the upgraded ANASEN detector<br />APS Division of Nuclear Physics (DNP) Fall Meeting; Boston, MA Boston, Suffolk County, Massachusetts, United States

# %%
# Save the map
m = getorg.orgmap.create_map_obj()
getorg.orgmap.output_html_cluster_map(location_dict, folder_name="talkmap", hashed_usernames=False)
# Out:
# 'Written map to talkmap/'
